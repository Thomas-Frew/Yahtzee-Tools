# %%
import pandas as pd

# %%
# Load dataset and eplace column names
dataset_name = "input_dataset.csv"
column_names = ["Ones", "Twos", "Threes", "Fours", "Fives", "Sixes", "Total", "Bonus", "3 of a Kind", "4 of a Kind", "Full House", "Small Straight", "Large Straight", "Chance", "Yahtzee", "Score"]

df = pd.read_csv(dataset_name, dtype=str, keep_default_na=False, names=column_names)
df
# Out:
#         Ones Twos Threes Fours Fives Sixes Total Bonus 3 of a Kind  \
# Sharon
# Sharon                                  18
# Sharon                                  18                      25
# Sharon                      12          18                      25
# Sharon     4                12          18                      25
# ...      ...  ...    ...   ...   ...   ...   ...   ...         ...
# William    2           9    16    20    18                      27
# William    2           9    16    20    18                      27
# William    2    0      9    16    20    18    65    35          27
# William    2    0      9    16    20    18    65    35          27
# William    2    0      9    16    20    18    65    35          27
#
#         4 of a Kind Full House Small Straight Large Straight Chance Yahtzee  \
# Sharon                                     30
# Sharon                                     30
# Sharon                                     30
# ...

# %%
# Replace player IDs with unique nonces
df.index = pd.factorize(df.index)[0]
df
# Out:
#    Ones Twos Threes Fours Fives Sixes Total Bonus 3 of a Kind 4 of a Kind  \
# 0
# 0                                  18
# 0                                  18                      25
# 0                      12          18                      25
# 0     4                12          18                      25
# ..  ...  ...    ...   ...   ...   ...   ...   ...         ...         ...
# 55    2           9    16    20    18                      27          29
# 55    2           9    16    20    18                      27          29
# 55    2    0      9    16    20    18    65    35          27          29
# 55    2    0      9    16    20    18    65    35          27          29
# 55    2    0      9    16    20    18    65    35          27          29
#
#    Full House Small Straight Large Straight Chance Yahtzee Score
# 0                         30                                 271
# 0                         30                                 271
# ...

# %%
# Export the dataset
df.to_csv('output_dataset.csv')
